# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df = pd.read_excel("/content/drive/MyDrive/Ecodrive/EcoDrive.xlsx",index_col="DOL Vehicle ID")

# %%
df.drop("Unnamed: 17", axis=1, inplace= True)

# %%
df.head()
# Out:
#                 VIN (1-10)     County          City State  Postal Code  \
# DOL Vehicle ID
# 261311557       1C4RJXN66R  Snohomish       Everett    WA      98204.0
# 210641315       KNDJX3AEXG       King        Renton    WA      98058.0
# 124517347       5YJ3E1EA3L       King       Seattle    WA      98125.0
# 7832933         1G1RC6S5XH     Kitsap  Port Orchard    WA      98367.0
# 235249262       5UXTA6C09P  Snohomish        Monroe    WA      98272.0
#
#                 Model Year       Make     Model  \
# DOL Vehicle ID
# 261311557             2024       JEEP  WRANGLER
# 210641315             2016        KIA      SOUL
# 124517347             2020      TESLA   MODEL 3
# 7832933               2017  CHEVROLET      VOLT
# 235249262             2023        BMW        X5
#
#                                  Electric Vehicle Type  \
# DOL Vehicle ID
# 261311557       Plug-in Hybrid Electric Vehicle (PHEV)
# 210641315               Battery Electric Vehicle (BEV)
# 124517347               Battery Electric Vehicle (BEV)
# 7832933         Plug-in Hybrid Electric Vehicle (PHEV)
# 235249262       Plug-in Hybrid Electric Vehicle (PHEV)
#
#                Clean Alternative Fuel Vehicle (CAFV) Eligibility  \
# DOL Vehicle ID
# 261311557                  Not eligible due to low battery range
# 210641315                Clean Alternative Fuel Vehicle Eligible
# 124517347                Clean Alternative Fuel Vehicle Eligible
# 7832933                  Clean Alternative Fuel Vehicle Eligible
# 235249262                Clean Alternative Fuel Vehicle Eligible
#
#                 Electric Range  Base MSRP  Legislative District  \
# DOL Vehicle ID
# 261311557                   21          0                  21.0
# 210641315                   93      31950                  11.0
# 124517347                  266          0                  46.0
# 7832933                     53          0                  26.0
# 235249262                   30          0                  39.0
#
#                                Vehicle Location  \
# DOL Vehicle ID
# 261311557       POINT (-122.2507211 47.8976713)
# 210641315       POINT (-122.1476337 47.4438471)
# 124517347         POINT (-122.304356 47.715668)
# 7832933         POINT (-122.6530052 47.4739066)
# 235249262         POINT (-121.968385 47.854897)
#
#                                              Electric Utility  \
# DOL Vehicle ID
# 261311557                              PUGET SOUND ENERGY INC
# 210641315       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 124517347        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 7832933                                PUGET SOUND ENERGY INC
# 235249262                              PUGET SOUND ENERGY INC
#
#                 2020 Census Tract
# DOL Vehicle ID
# 261311557            5.306104e+10
# 210641315            5.303303e+10
# 124517347            5.303300e+10
# 7832933              5.303509e+10
# 235249262            5.306105e+10

# %%
df.index.name = "No"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50000 entries, 261311557 to 261893215
# Data columns (total 16 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   VIN (1-10)                                         50000 non-null  object
#  1   County                                             49999 non-null  object
#  2   City                                               49999 non-null  object
#  3   State                                              50000 non-null  object
#  4   Postal Code                                        49999 non-null  float64
#  5   Model Year                                         50000 non-null  int64
#  6   Make                                               50000 non-null  object
#  7   Model                                              50000 non-null  object
#  8   Electric Vehicle Type                              50000 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  50000 non-null  object
#  10  Electric Range                                     50000 non-null  int64
#  11  Base MSRP                                          50000 non-null  int64
#  12  Legislative District                               49996 non-null  float64
#  13  Vehicle Location                                   49998 non-null  object
#  14  Electric Utility                                   49999 non-null  object
#  15  2020 Census Tract                                  49999 non-null  float64
# dtypes: float64(3), int64(3), object(10)
# memory usage: 6.5+ MB

# %%
df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'Vehicle Location',
#        'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# VIN (1-10)                                           0
# County                                               1
# City                                                 1
# State                                                0
# Postal Code                                          1
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 4
# Vehicle Location                                     2
# Electric Utility                                     1
# 2020 Census Tract                                    1
# dtype: int64

# %%
df["VIN (1-10)"].value_counts()
# Out:
# VIN (1-10)
# 7SAYGDEE7P    335
# 7SAYGDEEXP    334
# 7SAYGDEE6P    318
# 7SAYGDEE5P    317
# 7SAYGDEE2P    312
#              ...
# WA1H2BFZ2N      1
# SALWR2RY2L      1
# 3FMTK3R75N      1
# KNDCD3LD2N      1
# 55SWF4HBXJ      1
# Name: count, Length: 8097, dtype: int64

# %%
df["County"].value_counts()
# Out:
# County
# King            36500
# Clark            4687
# Snohomish        2881
# Kitsap           2177
# Thurston         1498
# Cowlitz           437
# Jefferson         367
# Yakima            318
# Pierce            261
# Island            205
# Whatcom           100
# Spokane            90
# Clallam            77
# Skagit             50
# Benton             48
# Chelan             35
# Stevens            30
# Mason              29
# San Juan           27
# Grays Harbor       24
# Klickitat          22
# Kittitas           18
# Douglas            17
# Walla Walla        17
# Grant              13
# Lewis              12
# Whitman            11
# Okanogan            9
# Skamania            7
# Wahkiakum           5
# Pacific             5
# Franklin            5
# Asotin              5
# Adams               4
# Montgomery          2
# Columbia            2
# Ferry               2
# Marin               1
# Pend Oreille        1
# Name: count, dtype: int64

# %%
df["County"]=df["County"].fillna("Not avalabel")

# %%
df[df["City"].isna()].index
# Out:
# Index([477613216], dtype='int64', name='No')

# %%
df.dropna(axis=0, how="any", inplace=True)

# %%
df.isna().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %%
df
# Out:
#            VIN (1-10)     County          City State  Postal Code  Model Year  \
# No
# 261311557  1C4RJXN66R  Snohomish       Everett    WA      98204.0        2024
# 210641315  KNDJX3AEXG       King        Renton    WA      98058.0        2016
# 124517347  5YJ3E1EA3L       King       Seattle    WA      98125.0        2020
# 7832933    1G1RC6S5XH     Kitsap  Port Orchard    WA      98367.0        2017
# 235249262  5UXTA6C09P  Snohomish        Monroe    WA      98272.0        2023
# ...               ...        ...           ...   ...          ...         ...
# 259039532  JM3KKEHA3R     Kitsap  Port Orchard    WA      98367.0        2024
# 150950824  KNDCC3LG9L       King     Sammamish    WA      98074.0        2020
# 177768734  5YJYGAEE5M       King     Sammamish    WA      98075.0        2021
# 251510157  KNDCS3LF7P     Skagit  Mount Vernon    WA      98273.0        2023
# 261893215  KM8KNDDFXR       King       Seattle    WA      98107.0        2024
#
#                 Make     Model                   Electric Vehicle Type  \
# No
# 261311557       JEEP  WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 210641315        KIA      SOUL          Battery Electric Vehicle (BEV)
# 124517347      TESLA   MODEL 3          Battery Electric Vehicle (BEV)
# 7832933    CHEVROLET      VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 235249262        BMW        X5  Plug-in Hybrid Electric Vehicle (PHEV)
# ...              ...       ...                                     ...
# 259039532      MAZDA     CX-90  Plug-in Hybrid Electric Vehicle (PHEV)
# 150950824        KIA      NIRO          Battery Electric Vehicle (BEV)
# 177768734      TESLA   MODEL Y          Battery Electric Vehicle (BEV)
# 251510157        KIA      NIRO  Plug-in Hybrid Electric Vehicle (PHEV)
# 261893215    HYUNDAI   IONIQ 5          Battery Electric Vehicle (BEV)
#
#            Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# No
# 261311557              Not eligible due to low battery range              21
# 210641315            Clean Alternative Fuel Vehicle Eligible              93
# 124517347            Clean Alternative Fuel Vehicle Eligible             266
# 7832933              Clean Alternative Fuel Vehicle Eligible              53
# 235249262            Clean Alternative Fuel Vehicle Eligible              30
# ...                                                      ...             ...
# 259039532              Not eligible due to low battery range              26
# 150950824            Clean Alternative Fuel Vehicle Eligible             239
# 177768734  Eligibility unknown as battery range has not b...               0
# 251510157            Clean Alternative Fuel Vehicle Eligible              33
# 261893215  Eligibility unknown as battery range has not b...               0
#
#            Base MSRP  Legislative District                 Vehicle Location  \
# No
# 261311557          0                  21.0  POINT (-122.2507211 47.8976713)
# 210641315      31950                  11.0  POINT (-122.1476337 47.4438471)
# 124517347          0                  46.0    POINT (-122.304356 47.715668)
# 7832933            0                  26.0  POINT (-122.6530052 47.4739066)
# 235249262          0                  39.0    POINT (-121.968385 47.854897)
# ...              ...                   ...                              ...
# 259039532          0                  26.0  POINT (-122.6530052 47.4739066)
# 150950824          0                  45.0  POINT (-122.0430602 47.6259676)
# 177768734          0                  41.0  POINT (-122.0181135 47.5880568)
# 251510157          0                  40.0  POINT (-122.3313378 48.4221418)
# 261893215          0                  36.0  POINT (-122.3788863 47.6702397)
#
#                                         Electric Utility  2020 Census Tract
# No
# 261311557                         PUGET SOUND ENERGY INC       5.306104e+10
# 210641315  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 124517347   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 7832933                           PUGET SOUND ENERGY INC       5.303509e+10
# 235249262                         PUGET SOUND ENERGY INC       5.306105e+10
# ...                                                  ...                ...
# 259039532                         PUGET SOUND ENERGY INC       5.303509e+10
# 150950824  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 177768734  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 251510157                         PUGET SOUND ENERGY INC       5.305795e+10
# 261893215   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
#
# [49995 rows x 16 columns]

# %%
df.describe()
# Out:
#         Postal Code    Model Year  Electric Range     Base MSRP  \
# count  49995.000000  49995.000000    49995.000000   49995.00000
# mean   98182.104130   2020.881508       54.427583     956.19902
# std      220.003585      2.931367       89.414636    7793.80585
# min    98001.000000   2000.000000        0.000000       0.00000
# 25%    98034.000000   2019.000000        0.000000       0.00000
# 50%    98109.000000   2022.000000        0.000000       0.00000
# 75%    98188.000000   2023.000000       53.000000       0.00000
# max    99403.000000   2025.000000      337.000000  184400.00000
#
#        Legislative District  2020 Census Tract
# count          49995.000000       4.999500e+04
# mean              31.644484       5.303403e+10
# std               14.757822       1.232078e+07
# min                1.000000       5.300195e+10
# 25%               18.000000       5.303301e+10
# 50%               36.000000       5.303302e+10
# 75%               45.000000       5.303303e+10
# max               49.000000       5.307794e+10

# %%
df["Base MSRP"].value_counts(dropna=False)
# Out:
# Base MSRP
# 0         49164
# 69900       322
# 31950        98
# 52900        59
# 54950        35
# 59900        34
# 64950        31
# 32250        30
# 44100        29
# 45600        24
# 36800        21
# 39995        21
# 36900        16
# 33950        16
# 55700        15
# 52650        15
# 34995        14
# 53400        12
# 81100         7
# 110950        7
# 184400        6
# 98950         6
# 90700         3
# 102000        3
# 89100         2
# 109000        2
# 43700         1
# 91250         1
# 75095         1
# Name: count, dtype: int64

# %% [markdown]
# As the Base MSRP is having 0 more 49000 times so we cannot replace with the mean value. So, we can count the number of occurance of the values and can replace with the more frequent value i.e mode

# %%
df["Base MSRP"].replace(to_replace=0, value=69900, inplace=True)
# Out:
# <ipython-input-17-5f0fb45494ec>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Base MSRP"].replace(to_replace=0, value=69900, inplace=True)

# %%
df.index.name= "Vehicle Id"

# %%
df.head()
# Out:
#             VIN (1-10)     County          City State  Postal Code  \
# Vehicle Id
# 261311557   1C4RJXN66R  Snohomish       Everett    WA      98204.0
# 210641315   KNDJX3AEXG       King        Renton    WA      98058.0
# 124517347   5YJ3E1EA3L       King       Seattle    WA      98125.0
# 7832933     1G1RC6S5XH     Kitsap  Port Orchard    WA      98367.0
# 235249262   5UXTA6C09P  Snohomish        Monroe    WA      98272.0
#
#             Model Year       Make     Model  \
# Vehicle Id
# 261311557         2024       JEEP  WRANGLER
# 210641315         2016        KIA      SOUL
# 124517347         2020      TESLA   MODEL 3
# 7832933           2017  CHEVROLET      VOLT
# 235249262         2023        BMW        X5
#
#                              Electric Vehicle Type  \
# Vehicle Id
# 261311557   Plug-in Hybrid Electric Vehicle (PHEV)
# 210641315           Battery Electric Vehicle (BEV)
# 124517347           Battery Electric Vehicle (BEV)
# 7832933     Plug-in Hybrid Electric Vehicle (PHEV)
# 235249262   Plug-in Hybrid Electric Vehicle (PHEV)
#
#            Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# Vehicle Id
# 261311557              Not eligible due to low battery range              21
# 210641315            Clean Alternative Fuel Vehicle Eligible              93
# 124517347            Clean Alternative Fuel Vehicle Eligible             266
# 7832933              Clean Alternative Fuel Vehicle Eligible              53
# 235249262            Clean Alternative Fuel Vehicle Eligible              30
#
#             Base MSRP  Legislative District                 Vehicle Location  \
# Vehicle Id
# 261311557       69900                  21.0  POINT (-122.2507211 47.8976713)
# 210641315       31950                  11.0  POINT (-122.1476337 47.4438471)
# 124517347       69900                  46.0    POINT (-122.304356 47.715668)
# 7832933         69900                  26.0  POINT (-122.6530052 47.4739066)
# 235249262       69900                  39.0    POINT (-121.968385 47.854897)
#
#                                          Electric Utility  2020 Census Tract
# Vehicle Id
# 261311557                          PUGET SOUND ENERGY INC       5.306104e+10
# 210641315   PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 124517347    CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 7832933                            PUGET SOUND ENERGY INC       5.303509e+10
# 235249262                          PUGET SOUND ENERGY INC       5.306105e+10

# %% [markdown]
# ### ***Q1. What is the total number of electric vehicles registered in each county?***

# %%
county_vehicle_count = df.groupby('County')['VIN (1-10)'].count().sort_values(ascending=False)

# %%
county_vehicle_count
# Out:
# County
# King            7073
# Clark           2512
# Kitsap          1529
# Snohomish       1478
# Thurston        1129
# Cowlitz          397
# Jefferson        335
# Yakima           286
# Pierce           234
# Island           198
# Whatcom           99
# Spokane           85
# Clallam           76
# Skagit            49
# Benton            48
# Chelan            35
# Stevens           30
# Mason             29
# San Juan          27
# Grays Harbor      24
# Klickitat         22
# Kittitas          18
# Douglas           17
# Walla Walla       17
# Grant             13
# Lewis             12
# Whitman           11
# Okanogan           9
# Skamania           7
# Asotin             5
# Franklin           5
# Wahkiakum          5
# Pacific            4
# Adams              4
# Ferry              2
# Columbia           2
# Pend Oreille       1
# Name: VIN (1-10), dtype: int64

# %%
total_no_vehicle = county_vehicle_count.sum()
# Out:
# 49995

# %% [markdown]
# ### ***Q2. which are the top 5 most popular electric vehicle models in the dataset***

# %%
top_model = df.groupby("Model")["VIN (1-10)"].count().sort_values(ascending=False)

# %%
top_5 = top_model.head(5)

# %%
plt.figure(figsize=(13, 7))
plt.bar(top_5.index, top_5.values)
plt.xlabel("Models")
plt.ylabel("No of Vehicles")
plt.title("Top 5 Most Models")
plt.show()

# %% [markdown]
# ### ***Q3. What is the average electric range of vehicles by type(BEV vs PHEV)?***

# %%
averageby_type = df.groupby('Electric Vehicle Type')['Electric Range'].mean()
averageby_type
# Out:
# Electric Vehicle Type
# Battery Electric Vehicle (BEV)            60.937907
# Plug-in Hybrid Electric Vehicle (PHEV)    30.606747
# Name: Electric Range, dtype: float64

# %% [markdown]
# ### ***Q4. How many vehicles are eligible for clean alternative fuel vehicle incentives?***

# %%
eligible = df[df["Clean Alternative Fuel Vehicle (CAFV) Eligibility"]=="Clean Alternative Fuel Vehicle Eligible"]
totall = eligible.shape[0]
print(f"total eligible vehicles are {totall}")
# Out:
# total eligible vehicles are 17613

# %% [markdown]
# ### ***Q5. what is the distribution of electric vehicles by model year?***

# %%
model_year= df['Model Year'].value_counts().sort_index()
plt.figure(figsize=(13, 7))
plt.bar(model_year.index, model_year.values)
plt.xlabel("Models year")
plt.ylabel("No of Vehicles")
plt.title("distribution of electric vehicles by model year")
plt.show()

# %% [markdown]
# ### ***Q6. Which cities have the highest number of registered electric vehicles?***

# %%
city = df.groupby("City")["VIN (1-10)"].count().sort_values(ascending=False)
top_city = city.head(5)
plt.figure(figsize=(13, 7))
plt.bar(top_city.index, top_city.values)
plt.xlabel("Cities")
plt.ylabel("No of Vehicles")
plt.title("Highest number of registered electric vehicles")
# Out:
# Text(0.5, 1.0, 'Highest number of registered electric vehicles')

# %% [markdown]
# ### ***Q7. What is the relationship between base MSRP and electric range?***

# %%
plt.figure(figsize=(13, 6))
plt.scatter(df['Base MSRP'], df['Electric Range'])
plt.xlabel("Base MSRP")
plt.ylabel("Electric Range")
plt.title("Relationship between Base MSRP and Electric Range")
plt.grid(True)
plt.show()

# %% [markdown]
# ### ***Q8. Which electric utility providers serve the most electric vehicles?***

# %%
ev_counts = df.groupby('Electric Utility')['Electric Utility'].count().sort_values(ascending=False)

top_utility_providers = ev_counts.head(5)

plt.figure(figsize=(13, 7))
plt.bar(top_utility_providers.index, top_utility_providers.values)
plt.xlabel("Electric Utility Provider")
plt.ylabel("Number of Electric Vehicles Served")
plt.title("Top Electric Utility Providers Serving the Most Electric Vehicles")
plt.xticks(rotation=45, ha='right')
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'),
#   Text(1, 0, 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)'),
#   Text(2, 0, 'PUGET SOUND ENERGY INC'),
#   Text(3, 0, 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)'),
#   Text(4, 0, 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF COWLITZ COUNTY')])

# %% [markdown]
# ### ***Q9 What percentage of vehicles are plug-in hybrid electric vehicles(PHEVs)***

# %%
phev_percentage = (df['Electric Vehicle Type'].value_counts(normalize=True)['Plug-in Hybrid Electric Vehicle (PHEV)']) * 100

# Display the result

print(f"Percentage of vehicles that are PHEVs: {phev_percentage:.2f}%")

other_percentage = 100 - phev_percentage
# Create labels and data for the pie chart
labels = ['PHEV', 'Other']
sizes = [phev_percentage, other_percentage]
colors = ['aqua', 'green']  # Specify colors for PHEV and Other

# Create the pie chart
plt.figure(figsize=(6, 6))  # Adjust figure size if needed
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title("Percentage of Plug-in Hybrid Electric Vehicles (PHEVs)")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ### ***Q10. Which legislative districts have the highest EV Adoption rates?***

# %%
ev_counts_by_district = df.groupby('Legislative District')['Electric Vehicle Type'].count()

# 2. Group by Legislative District and count unique VINs (1-10) for total vehicles
total_vehicles_by_district = df.groupby('Legislative District')['VIN (1-10)'].nunique()

# 3. Calculate EV Adoption Rate per District
ev_adoption_rate = (ev_counts_by_district / total_vehicles_by_district) * 100

# 4. Sort by Adoption Rate (Descending)
sorted_districts = ev_adoption_rate.sort_values(ascending=False)

# 5. Get Top Districts (e.g., Top 10)
top_districts = sorted_districts.head(10)

# 6. Display Results
print("Legislative Districts with Highest EV Adoption Rates (using VIN):")
print(top_districts)
